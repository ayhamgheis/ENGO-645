# %% [markdown]
# # Test Notebook - System Check
# Testing out the notebook generation!

# %%
import random
import datetime

# Generate random data
names = ['Alice', 'Bob', 'Charlie', 'Diana', 'Eve']
print(f"Today is {datetime.date.today()}")
print(f"Random person: {random.choice(names)}")
# Out:
# Today is 2026-01-17
# Random person: Eve
